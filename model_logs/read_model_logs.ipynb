# %%
import pandas as pd

df = pd.read_csv('./model_logs/v17.1.csv')
df
# Out:
#     iteration  reward_mean  length_mean  games          loss
# 0         500        -1.00         2.00      8  1.328566e+06
# 1        1000        -1.00         2.00      9  6.216533e+07
# 2        1500        -1.00         2.00     11  3.820874e+08
# 3        2000        -1.00         2.00      8  7.174175e+08
# 4        2500        -0.90         2.10     10  1.295303e+09
# 5        3000        -1.00         2.00      8  1.379353e+09
# 6        3500        -1.00         2.00     10  1.297212e+09
# 7        4000        -1.00         2.00      9  2.971908e+09
# 8        4500        -1.00         2.00      8  1.799003e+09
# 9        5000        -1.00         2.00      8  4.573027e+09
# 10       5500        -1.00         2.00      8  7.662091e+09
# 11       6000        -0.90         2.10     10  3.967030e+09
# 12       6500        -1.00         2.00      8  8.097836e+09
# 13       7000        -1.00         2.00     10  8.341304e+09
# ...

# %%
loss = df['loss']
loss.plot()
# Out:
# <AxesSubplot:>
