# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('v17.1.csv')
df
# Out:
#      iteration  reward_mean  length_mean  games      loss
# 0          500        -1.00         2.00     11  0.032767
# 1         1000        -0.88         2.12      8  0.017455
# 2         1500        -1.00         2.00      9  0.011626
# 3         2000        -1.00         2.00      8  0.015207
# 4         2500        -0.88         2.12      8  0.005102
# ..         ...          ...          ...    ...       ...
# 395     198000        17.75        20.75      8  0.007000
# 396     198500        11.12        14.12      8  0.010800
# 397     199000        20.75        23.75      8  0.017731
# 398     199500        19.50        22.50      8  0.004091
# 399     200000        18.50        21.50      8  0.025932
#
# [400 rows x 5 columns]

# %%
loss = df['loss']
loss.plot()
plt.legend(['loss'])

# %%
reward = df['reward_mean']
reward.plot()
plt.legend(['reward mean'])

# %%
length_mean = df['length_mean']
length_mean.plot()
plt.legend(['length mean'])
