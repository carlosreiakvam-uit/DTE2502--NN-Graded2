# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('v17.1.csv')
df
# Out:
#     iteration  reward_mean  length_mean  games      loss
# 0         500        -0.75         2.25      8  0.004687
# 1        1000         0.25         2.25      8  0.008510
# 2        1500        -0.50         2.00     12  0.007063
# 3        2000         0.00         2.00      8  0.008471
# 4        2500         0.75         2.88      8  0.001688
# 5        3000         0.38         2.38      8  0.005211
# 6        3500         0.60         2.90     10  0.005461
# 7        4000         0.00         2.00      8  0.005658
# 8        4500         1.20         3.60     10  0.002058
# 9        5000         0.00         2.00      8  0.001790
# 10       5500         0.25         2.25      8  0.005753
# 11       6000         0.67         2.89      9  0.001061
# 12       6500         0.00         2.00      8  0.002740
# 13       7000         0.50         2.62      8  0.002399
# 14       7500        -0.12         2.00      8  0.002517
# 15       8000         0.12         2.12      8  0.003191
# 16       8500         0.38         2.38      8  0.001219
# 17       9000         0.50         2.50      8  0.006426
# 18       9500         0.12         2.12      8  0.008068
# 19      10000         0.12         2.12      8  0.008865
# 20      10500         0.12         2.12      8  0.001076
# 21      11000         0.50         2.50      8  0.004559
# 22      11500        -0.10         2.30     10  0.007938
# 23      12000         0.25         2.38      8  0.005300
# 24      12500         0.25         2.38      8  0.012041
# 25      13000         0.38         2.38      8  0.003370
# 26      13500         0.00         2.00      8  0.020010
# 27      14000         0.12         2.12      8  0.003224
# 28      14500         0.12         2.12      8  0.005634
# 29      15000         0.12         2.12      8  0.019236
# 30      15500         0.50         2.50      8  0.011256
# 31      16000         0.50         2.80     10  0.003358
# 32      16500         0.25         2.25      8  0.002476
# 33      17000         1.12         3.25      8  0.017405
# 34      17500         0.38         2.38      8  0.011397
# 35      18000         1.40         3.70     10  0.019988
# 36      18500         0.22         2.56      9  0.023757
# 37      19000         0.25         2.25      8  0.005183
# 38      19500         0.12         2.38      8  0.014425
# 39      20000         0.25         2.25      8  0.005801

# %%
loss = df['loss']
loss.plot()
plt.legend(['loss'])

# %%
reward = df['reward_mean']
reward.plot()
plt.legend(['reward mean'])

# %%
length_mean = df['length_mean']
length_mean.plot()
# Out:
# <AxesSubplot:>
