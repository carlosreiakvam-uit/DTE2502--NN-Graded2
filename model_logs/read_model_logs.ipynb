# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('v17.1.csv')
df
# Out:
#     iteration  reward_mean  length_mean  games          loss
# 0         500        -1.00         2.00      8  1.031828e+06
# 1        1000        -1.00         2.00      9  3.226679e+06
# 2        1500        -1.00         2.00     10  2.698262e+07
# 3        2000        -1.00         2.00      8  1.506128e+08
# 4        2500        -1.00         2.00      8  2.008139e+08
# 5        3000        -1.00         2.00     10  2.757722e+08
# 6        3500        -1.00         2.00      8  4.783487e+08
# 7        4000        -1.00         2.00      8  5.358682e+08
# 8        4500        -1.00         2.00      9  1.371910e+09
# 9        5000        -1.00         2.00      8  4.969434e+09
# 10       5500        -1.00         2.00      8  5.156526e+09
# 11       6000        -1.00         2.00     10  2.841005e+09
# 12       6500        -1.00         2.00      9  3.626346e+09
# 13       7000        -0.88         2.12      8  6.242491e+09
# 14       7500        -1.00         2.00     10  6.061870e+09
# 15       8000        -1.00         2.00      9  1.227340e+10
# 16       8500        -1.00         2.00      8  6.453032e+09
# 17       9000        -1.00         2.00      8  1.689235e+10
# 18       9500        -1.00         2.00      9  1.187938e+10
# 19      10000        -1.00         2.00     10  1.482984e+10
# 20      10500        -1.00         2.00      8  2.100171e+10
# 21      11000        -0.90         2.10     10  2.272520e+10
# 22      11500        -1.00         2.00      8  3.078661e+10
# 23      12000        -0.89         2.11      9  3.981071e+10
# 24      12500        -1.00         2.00      8  1.397427e+10
# 25      13000        -0.88         2.12      8  3.881832e+10
# 26      13500        -1.00         2.00     11  3.218550e+10
# 27      14000        -1.00         2.00     10  5.099476e+10
# 28      14500        -0.89         2.11      9  6.175886e+10
# 29      15000        -0.80         2.20     10  2.798635e+10
# 30      15500        -1.00         2.00      8  1.076167e+11
# 31      16000        -0.89         2.11      9  1.286485e+11
# 32      16500        -1.00         2.00     10  7.717059e+10
# 33      17000        -1.00         2.00      8  6.931243e+10
# 34      17500        -1.00         2.00      8  9.264858e+10
# 35      18000        -1.00         2.00      9  2.195210e+11
# 36      18500        -1.00         2.00      8  1.539004e+11
# 37      19000        -0.75         2.25      8  1.394868e+11
# 38      19500        -1.00         2.00      9  1.422621e+11
# 39      20000        -0.88         2.12      8  9.626146e+10

# %%
loss = df['loss']
loss.plot()
plt.legend(['loss'])

# %%
reward = df['reward_mean']
reward.plot()
# Out:
# <AxesSubplot:>

# %%
length_mean = df['length_mean']
length_mean.plot()
# Out:
# <AxesSubplot:>
