# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('v17.1.csv')
df
# Out:
#     iteration  reward_mean  length_mean  games      loss
# 0         500         0.38         2.38      8  0.004672
# 1        1000         0.00         2.00      8  0.007063
# 2        1500         0.38         2.50      8  0.003308
# 3        2000         0.88         2.88      8  0.003764
# 4        2500         1.00         3.00      8  0.004285
# 5        3000         0.38         2.38      8  0.001450
# 6        3500         1.00         3.22      9  0.001635
# 7        4000         2.60         5.10     10  0.004161
# 8        4500         3.75         6.75      8  0.003985
# 9        5000         2.90         5.50     10  0.001379
# 10       5500         4.12         7.12      8  0.004813
# 11       6000         3.75         6.75      8  0.008260
# 12       6500         5.25         8.25      8  0.003278
# 13       7000         3.38         6.38      8  0.017145
# 14       7500         4.50         7.50      8  0.002799
# 15       8000         5.00         8.00      8  0.009063
# 16       8500         5.12         8.12      8  0.002799
# 17       9000         3.11         6.11      9  0.002274
# 18       9500         4.12         7.12      8  0.004546
# 19      10000         4.38         7.38      8  0.003655
# 20      10500         4.75         7.75      8  0.015799
# 21      11000         4.12         7.12      8  0.002587
# 22      11500         2.50         5.50      8  0.014389
# 23      12000         5.38         8.38      8  0.004042
# 24      12500         3.88         6.88      8  0.002680
# 25      13000         5.50         8.50      8  0.003316
# 26      13500         5.25         8.25      8  0.003422
# 27      14000         5.62         8.62      8  0.011108
# 28      14500         9.25        12.25      8  0.022947
# 29      15000         6.75         9.75      8  0.057470
# 30      15500         3.50         6.50      8  0.005352
# 31      16000         6.38         9.38      8  0.033720
# 32      16500         2.62         5.62      8  0.049791
# 33      17000         4.25         7.25      8  0.019506
# 34      17500         4.25         7.25      8  0.005043
# 35      18000         6.00         9.00      8  0.029769
# 36      18500         4.50         7.50      8  0.037016
# 37      19000         5.25         8.25      8  0.018380
# 38      19500         5.25         8.25      8  0.034773
# 39      20000         6.88         9.88      8  0.003851

# %%
loss = df['loss']
loss.plot()
plt.legend(['loss'])

# %%
reward = df['reward_mean']
reward.plot()
# Out:
# <AxesSubplot:>

# %%
length_mean = df['length_mean']
length_mean.plot()
# Out:
# <AxesSubplot:>
