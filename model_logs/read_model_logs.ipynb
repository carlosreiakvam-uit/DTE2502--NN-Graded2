# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('v17.1.csv')
df
# Out:
#     iteration  reward_mean  length_mean  games      loss
# 0         500        -0.88         2.12      8  0.040048
# 1        1000        -0.88         2.12      8  0.029065
# 2        1500        -1.00         2.00      8  0.015062
# 3        2000        -0.40         2.10     10  0.041688
# 4        2500        -0.55         2.00     11  0.038664
# 5        3000        -0.88         2.12      8  0.034650
# 6        3500        -1.00         2.00      8  0.030586
# 7        4000         0.00         2.12      8  0.039634
# 8        4500        -0.30         2.10     10  0.026769
# 9        5000        -0.25         2.00      8  0.041557
# 10       5500         0.00         2.25      8  0.018540
# 11       6000        -0.25         2.00      8  0.020995
# 12       6500        -0.22         2.00      9  0.029222
# 13       7000         0.12         2.12      8  0.031370
# 14       7500        -0.11         2.33      9  0.034566
# 15       8000        -0.12         2.00      8  0.038917
# 16       8500        -0.11         2.22      9  0.028463
# 17       9000        -0.25         2.00      8  0.019871
# 18       9500         0.12         2.12      8  0.019671
# 19      10000        -0.38         2.12      8  0.019573
# 20      10500         0.00         2.12      8  0.019615
# 21      11000        -0.12         2.00      8  0.026949
# 22      11500        -0.25         2.00      8  0.027669
# 23      12000        -0.25         2.00      8  0.030465
# 24      12500         0.00         2.00      8  0.016400
# 25      13000        -0.30         2.10     10  0.015632
# 26      13500         0.00         2.00      8  0.018034
# 27      14000        -0.12         2.00      8  0.026583
# 28      14500         0.00         2.12      8  0.021673
# 29      15000         0.12         2.12      8  0.020634
# 30      15500        -0.44         2.00      9  0.023311
# 31      16000         0.12         2.12      8  0.029411
# 32      16500        -0.25         2.00      8  0.015390
# 33      17000         0.00         2.12      8  0.021493
# 34      17500         0.00         2.00      8  0.017096
# 35      18000        -0.33         2.11      9  0.020214
# 36      18500        -0.12         2.25      8  0.021691
# 37      19000        -0.12         2.00      8  0.016783
# 38      19500         0.00         2.12      8  0.014668
# 39      20000         0.25         2.50      8  0.016288

# %%
loss = df['loss']
loss.plot()
plt.legend(['loss'])

# %%
reward = df['reward_mean']
reward.plot()
plt.legend(['reward mean'])

# %%
length_mean = df['length_mean']
length_mean.plot()
# Out:
# <AxesSubplot:>
